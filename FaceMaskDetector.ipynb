# %% [markdown]
# <a href="https://colab.research.google.com/github/Nimra-Fayaz/FaceMaskDetector/blob/main/FaceMaskDetector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.5/615.5 kB 6.8 MB/s eta 0:00:00

# %%
import os

# Set the locale to UTF-8
os.environ['LC_ALL'] = 'en_US.UTF-8'
os.environ['LANG'] = 'en_US.UTF-8'

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 75.9MB/s]

# %%
# !touch data.yaml

# %%
model.train(data="/content/data.yaml", epochs=10)  # train the model
# Out:
# Ultralytics YOLOv8.0.187 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/DataSetOfMaskDetection/test/images" , save = True , save_txt = True)
# Out:
# image 1/200 /content/drive/MyDrive/DataSetOfMaskDetection/test/images/0209-00176-076b1_jpg.rf.68ca9cf32fcefea879d225af4a7c3d44.jpg: 448x640 3 masks, 2 no-masks, 76.3ms
# image 2/200 /content/drive/MyDrive/DataSetOfMaskDetection/test/images/0450908675_50159485_mutation-virus-chine-inquietude_jpg.rf.bda5fb5e13aac2a13eacab5ee4938218.jpg: 416x640 3 masks, 2 no-masks, 68.3ms
# image 3/200 /content/drive/MyDrive/DataSetOfMaskDetection/test/images/0_Concern-In-China-As-Mystery-Virus-Spreads_jpg.rf.11f76c39529068ff636fa2242afffa1d.jpg: 352x640 3 masks, 128.1ms
# image 4/200 /content/drive/MyDrive/DataSetOfMaskDetection/test/images/0_Concern-In-China-As-Mystery-Virus-Spreads_jpg.rf.8817cb47eb5195e35bd6eee4bc773e68.jpg: 352x640 3 masks, 26.2ms
# image 5/200 /content/drive/MyDrive/DataSetOfMaskDetection/test/images/1224331650_g_400-w_g_jpg.rf.4f6fa6b1a07d7011f5e32cf441b0d8d8.jpg: 608x640 2 masks, 126.4ms
# ...

# %%
os.system('yolo detect predict model="/content/runs/detect/train/weights/best.pt" source="/content/Untitled design.mp4"')
# Out:
# 0
